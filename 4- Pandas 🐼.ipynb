# %% [markdown]
# # Saturdays.AI Guadalajara 4a Ed.
# ### Pandas
#
# #### Luis Román
#
# ### Agosto de 2022

# %% [markdown]
# Pandas o Python Data Analysis Library, es una de las mejores librerías para manipulación de datos

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\softs\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in d:\softs\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\softs\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in d:\softs\anaconda3\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in d:\softs\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
# Importación
import pandas as pd

# %% [markdown]
# ### Pandas Series

# %%
# Iniciar un pandas series a partir de una lista de Python
frutas = ["Plátano", "Fresa", "Mango", "Durazno"]
frutas_series = pd.Series(frutas)
print(frutas_series)
print(type(frutas_series))
# Out:
# 0    Plátano
# 1      Fresa
# 2      Mango
# 3    Durazno
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
# A partir de un diccionario
transportes = {1:"Bicicleta", 2:"Motocicleta", 3:"Automóvil", 4:"Camión"}
transportes_series = pd.Series(transportes)
transportes_series
# Out:
# 1      Bicicleta
# 2    Motocicleta
# 3      Automóvil
# 4         Camión
# dtype: object

# %%
# Acceder a los valores de una serie de pandas usando el índice
transportes_series[1]
# Out:
# 'Bicicleta'

# %% [markdown]
# ### Dataframes

# %%
# Diccionario de platillos con su nombre y precio
platillos = {
    "nombre":["Hot-Cakes", "Molletes", "Quesadillas"],
    "precio":[120,50,60]
}

df = pd.DataFrame(platillos)
df
# Out:
#         nombre  precio
# 0    Hot-Cakes     120
# 1     Molletes      50
# 2  Quesadillas      60

# %%
df['nombre']
# Out:
# 0      Hot-Cakes
# 1       Molletes
# 2    Quesadillas
# Name: nombre, dtype: object

# %%
# Verificar los índices
print(df.columns)

print(df.index)
# Out:
# Index(['nombre', 'precio'], dtype='object')
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# Pandas no cuenta con dataframes de prueba como R, por lo que para usar datos de prueba podemos utilizar las funciones generadoras de pd.util.testing https://towardsdatascience.com/4-pandas-tricks-that-most-people-dont-know-86a70a007993,
# métodos que actualmente no aparecen en la documentación.
#
# O podemos acceder al amplio catálogo de Kaggle https://www.kaggle.com/datasets

# %%
# Dataframes de prueba
# Generar un df con datos mezclados
df_prueba = pd.util.testing.makeMixedDataFrame()
df_prueba
# Out:
# D:\Softs\anaconda3\lib\site-packages\pandas\util\__init__.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#      A    B     C          D
# 0  0.0  0.0  foo1 2009-01-01
# 1  1.0  1.0  foo2 2009-01-02
# 2  2.0  0.0  foo3 2009-01-05
# 3  3.0  1.0  foo4 2009-01-06
# 4  4.0  0.0  foo5 2009-01-07

# %% [markdown]
# ### Dataframes desde un archivo (csv, xml, json)

# %% [markdown]
# Para consulta: https://pandas.pydata.org/docs/reference/io.html

# %% [markdown]
# #### csv

# %%
"""
Podemos indicar el separador mediante el argumento "sep", 
La localización del encabezado usando "header"
y sobreescribir los nombres de las columnas con "names"
"""
df_peliculas = pd.read_csv('TopAnimatedImDb.csv', header=0)
df_peliculas
# Out:
#                                 Title  Rating      Votes     Gross  \
# 0       Sen to Chihiro no kamikakushi     8.6    747,148   $10.06M
# 1                       The Lion King     8.5  1,041,158  $422.78M
# 2                      Hotaru no haka     8.5    272,469       NaN
# 3                      Kimi no na wa.     8.4    259,975    $5.02M
# 4   Spider-Man: Into the Spider-Verse     8.4    510,227  $190.24M
# ..                                ...     ...        ...       ...
# 80                      Kung Fu Panda     7.6    463,897  $215.43M
# 81                              Mulan     7.6    284,542  $120.62M
# 82                 The Little Mermaid     7.6    260,026  $111.54M
# 83                    The Jungle Book     7.6    181,528  $141.84M
# 84    Snow White and the Seven Dwarfs     7.6    197,860  $184.93M
#
#                  Genre  Metascore Certificate             Director  Year  \
# 0    Adventure, Family       96.0           U       Hayao Miyazaki  2001
# 1     Adventure, Drama       88.0           U         Roger Allers  1994
# 2           Drama, War       94.0           U        Isao Takahata  1988
# 3       Drama, Fantasy       79.0           U       Makoto Shinkai  2016
# 4    Action, Adventure       87.0           U      Bob Persichetti  2018
# ..                 ...        ...         ...                  ...   ...
# 80   Action, Adventure       74.0           U         Mark Osborne  2008
# 81   Adventure, Comedy       71.0           U        Tony Bancroft  1998
# 82   Adventure, Comedy       88.0           U         Ron Clements  1989
# 83   Adventure, Comedy       65.0           U  Wolfgang Reitherman  1967
# 84   Adventure, Family       95.0           U     William Cottrell  1937
#
#                                           Description  Runtime
# 0   ["\nDuring her family's move to the suburbs, a...  125 min
# 1   ['\nLion prince Simba and his father are targe...   88 min
# 2   ['\nA young boy and his little sister struggle...   89 min
# 3   ['\nTwo strangers find themselves linked in a ...  106 min
# 4   ['\nTeen Miles Morales becomes the Spider-Man ...  117 min
# ..                                                ...      ...
# 80  ["\nTo everyone's surprise, including his own,...   92 min
# 81  ["\nTo save her father from death in the army,...   88 min
# 82  ["\nA mermaid princess makes a Faustian bargai...   83 min
# 83  ['\nBagheera the Panther and Baloo the Bear ha...   78 min
# 84  ['\nExiled into the dangerous forest by her wi...   83 min
#
# [85 rows x 11 columns]

# %% [markdown]
# #### xml

# %%
df_libros = pd.read_xml('books.xml')
df_libros
# Out:
#        id                author                                   title  \
# 0   bk101  Gambardella, Matthew                   XML Developer's Guide
# 1   bk102            Ralls, Kim                           Midnight Rain
# 2   bk103           Corets, Eva                         Maeve Ascendant
# 3   bk104           Corets, Eva                         Oberon's Legacy
# 4   bk105           Corets, Eva                      The Sundered Grail
# 5   bk106      Randall, Cynthia                             Lover Birds
# 6   bk107        Thurman, Paula                           Splish Splash
# 7   bk108         Knorr, Stefan                         Creepy Crawlies
# 8   bk109          Kress, Peter                            Paradox Lost
# 9   bk110          O'Brien, Tim   Microsoft .NET: The Programming Bible
# 10  bk111          O'Brien, Tim           MSXML3: A Comprehensive Guide
# 11  bk112           Galos, Mike  Visual Studio 7: A Comprehensive Guide
#
#               genre  price publish_date  \
# 0          Computer  44.95   2000-10-01
# 1           Fantasy   5.95   2000-12-16
# 2           Fantasy   5.95   2000-11-17
# 3           Fantasy   5.95   2001-03-10
# 4           Fantasy   5.95   2001-09-10
# 5           Romance   4.95   2000-09-02
# 6           Romance   4.95   2000-11-02
# 7            Horror   4.95   2000-12-06
# 8   Science Fiction   6.95   2000-11-02
# 9          Computer  36.95   2000-12-09
# 10         Computer  36.95   2000-12-01
# 11         Computer  49.95   2001-04-16
#
#                                           description
# 0   An in-depth look at creating applications \n  ...
# 1   A former architect battles corporate zombies, ...
# 2   After the collapse of a nanotechnology \n     ...
# 3   In post-apocalypse England, the mysterious \n ...
# 4   The two daughters of Maeve, half-sisters, \n  ...
# 5   When Carla meets Paul at an ornithology \n    ...
# 6   A deep sea diver finds true love twenty \n    ...
# 7   An anthology of horror stories about roaches,\...
# 8   After an inadvertant trip through a Heisenberg...
# 9   Microsoft's .NET initiative is explored in \n ...
# 10  The Microsoft MSXML3 parser is covered in \n  ...
# 11  Microsoft Visual Studio 7 is explored in depth...

# %% [markdown]
# #### json

# %%
df_posts = pd.read_json('posts.json')
df_posts
# Out:
#     userId   id                                              title  \
# 0        1    1  sunt aut facere repellat provident occaecati e...
# 1        1    2                                       qui est esse
# 2        1    3  ea molestias quasi exercitationem repellat qui...
# 3        1    4                               eum et est occaecati
# 4        1    5                                 nesciunt quas odio
# ..     ...  ...                                                ...
# 95      10   96  quaerat velit veniam amet cupiditate aut numqu...
# 96      10   97         quas fugiat ut perspiciatis vero provident
# 97      10   98                        laboriosam dolor voluptates
# 98      10   99  temporibus sit alias delectus eligendi possimu...
# 99      10  100              at nam consequatur ea labore ea harum
#
#                                                  body
# 0   quia et suscipit\nsuscipit recusandae consequu...
# 1   est rerum tempore vitae\nsequi sint nihil repr...
# 2   et iusto sed quo iure\nvoluptatem occaecati om...
# 3   ullam et saepe reiciendis voluptatem adipisci\...
# 4   repudiandae veniam quaerat sunt sed\nalias aut...
# ..                                                ...
# 95  in non odio excepturi sint eum\nlabore volupta...
# 96  eum non blanditiis soluta porro quibusdam volu...
# 97  doloremque ex facilis sit sint culpa\nsoluta a...
# 98  quo deleniti praesentium dicta non quod\naut e...
# 99  cupiditate quo est a modi nesciunt soluta\nips...
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Descripción del dataframe

# %%
# Mostrar los estadísticos básicos
df_peliculas.describe()
# Out:
#           Rating  Metascore         Year
# count  85.000000  80.000000    85.000000
# mean    7.922353  80.850000  2003.211765
# std     0.257449   8.965616    15.255830
# min     7.600000  59.000000  1937.000000
# 25%     7.700000  74.000000  1995.000000
# 50%     7.900000  82.000000  2007.000000
# 75%     8.100000  87.000000  2014.000000
# max     8.600000  96.000000  2021.000000

# %%
# Mostrar la forma de un df
df_peliculas.shape
# Out:
# (85, 11)

# %%
# Información del df
df_peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        85 non-null     object
#  1   Rating       85 non-null     float64
#  2   Votes        85 non-null     object
#  3   Gross        50 non-null     object
#  4   Genre        85 non-null     object
#  5   Metascore    80 non-null     float64
#  6   Certificate  84 non-null     object
#  7   Director     85 non-null     object
#  8   Year         85 non-null     int64
#  9   Description  85 non-null     object
#  10  Runtime      85 non-null     object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 7.4+ KB

# %%
# Conteo de valores
df_peliculas.count()
# Out:
# Title          85
# Rating         85
# Votes          85
# Gross          50
# Genre          85
# Metascore      80
# Certificate    84
# Director       85
# Year           85
# Description    85
# Runtime        85
# dtype: int64

# %%
# Obtener las filas superiores
df_peliculas.head()
# Out:
#                                Title  Rating      Votes     Gross  \
# 0      Sen to Chihiro no kamikakushi     8.6    747,148   $10.06M
# 1                      The Lion King     8.5  1,041,158  $422.78M
# 2                     Hotaru no haka     8.5    272,469       NaN
# 3                     Kimi no na wa.     8.4    259,975    $5.02M
# 4  Spider-Man: Into the Spider-Verse     8.4    510,227  $190.24M
#
#                 Genre  Metascore Certificate         Director  Year  \
# 0   Adventure, Family       96.0           U   Hayao Miyazaki  2001
# 1    Adventure, Drama       88.0           U     Roger Allers  1994
# 2          Drama, War       94.0           U    Isao Takahata  1988
# 3      Drama, Fantasy       79.0           U   Makoto Shinkai  2016
# 4   Action, Adventure       87.0           U  Bob Persichetti  2018
#
#                                          Description  Runtime
# 0  ["\nDuring her family's move to the suburbs, a...  125 min
# 1  ['\nLion prince Simba and his father are targe...   88 min
# 2  ['\nA young boy and his little sister struggle...   89 min
# 3  ['\nTwo strangers find themselves linked in a ...  106 min
# 4  ['\nTeen Miles Morales becomes the Spider-Man ...  117 min

# %%
# Ordenar el dataframe
df_peliculas.sort_values('Year')
# Out:
#                                  Title  Rating    Votes     Gross  \
# 84     Snow White and the Seven Dwarfs     7.6  197,860  $184.93M
# 74                            Fantasia     7.7   96,094   $76.41M
# 83                     The Jungle Book     7.6  181,528  $141.84M
# 73                  La planète sauvage     7.7   31,226    $0.19M
# 37            Kaze no tani no Naushika     8.0  168,233       NaN
# ..                                 ...     ...      ...       ...
# 60                         Toy Story 4     7.7  245,779  $434.04M
# 24                         WolfWalkers     8.0   31,618       NaN
# 12  Kimetsu no Yaiba: Mugen Ressha-Hen     8.2   55,255       NaN
# 25                                Soul     8.0  319,513       NaN
# 75       The Mitchells vs the Machines     7.6  105,707       NaN
#
#                  Genre  Metascore Certificate             Director  Year  \
# 84   Adventure, Family       95.0           U     William Cottrell  1937
# 74     Family, Fantasy       96.0           U          James Algar  1940
# 83   Adventure, Comedy       65.0           U  Wolfgang Reitherman  1967
# 73              Sci-Fi       73.0           U          René Laloux  1973
# 37   Adventure, Sci-Fi       86.0           U       Hayao Miyazaki  1984
# ..                 ...        ...         ...                  ...   ...
# 60   Adventure, Comedy       84.0           U          Josh Cooley  2019
# 24   Adventure, Family       87.0          UA           Tomm Moore  2020
# 12   Action, Adventure       72.0          UA       Haruo Sotozaki  2020
# 25   Adventure, Comedy       83.0           U          Pete Docter  2020
# 75   Adventure, Comedy       81.0          13       Michael Rianda  2021
#
#                                           Description  Runtime
# 84  ['\nExiled into the dangerous forest by her wi...   83 min
# 74  ['\nA collection of animated interpretations o...  125 min
# 83  ['\nBagheera the Panther and Baloo the Bear ha...   78 min
# 73  ['\nOn a faraway planet where blue giants rule...   72 min
# 37  ['\nWarrior and pacifist Princess Nausicaä des...  117 min
# ..                                                ...      ...
# 60  ['\nWhen a new toy called "Forky" joins Woody ...  100 min
# 24  ['\nA young apprentice hunter and her father j...  103 min
# 12  ["\nAfter his family was brutally murdered and...  117 min
# 25  ['\nAfter landing the gig of a lifetime, a New...  100 min
# 75  ["\nA quirky, dysfunctional family's road trip...  114 min
#
# [85 rows x 11 columns]

# %% [markdown]
# ### Filtrado de datos

# %% [markdown]
# ![imagen.png](attachment:imagen.png)
#
# Consulta a profundidad:
#
# https://www.educba.com/pandas-loc-vs-iloc/
# https://towardsdatascience.com/loc-vs-iloc-in-pandas-heres-the-difference-16cd4bcbecab

# %% [markdown]
# #### loc

# %% [markdown]
# Filtrado a través de labels, inclusivo.

# %%
df_peliculas.loc[0:5, ['Title','Genre']]
# Out:
#                                Title               Genre
# 0      Sen to Chihiro no kamikakushi   Adventure, Family
# 1                      The Lion King    Adventure, Drama
# 2                     Hotaru no haka          Drama, War
# 3                     Kimi no na wa.      Drama, Fantasy
# 4  Spider-Man: Into the Spider-Verse   Action, Adventure
# 5                               Coco   Adventure, Comedy

# %% [markdown]
# #### iloc

# %% [markdown]
# Filtrado a través de índice, no inclusivo

# %%
# Traer todas las filas, pero basarse por índice de las columnas
df_peliculas.iloc[0:5, 0:5]
# Out:
#                                Title  Rating      Votes     Gross  \
# 0      Sen to Chihiro no kamikakushi     8.6    747,148   $10.06M
# 1                      The Lion King     8.5  1,041,158  $422.78M
# 2                     Hotaru no haka     8.5    272,469       NaN
# 3                     Kimi no na wa.     8.4    259,975    $5.02M
# 4  Spider-Man: Into the Spider-Verse     8.4    510,227  $190.24M
#
#                 Genre
# 0   Adventure, Family
# 1    Adventure, Drama
# 2          Drama, War
# 3      Drama, Fantasy
# 4   Action, Adventure

# %%
df_peliculas.iloc[:3, 3:]
# Out:
#       Gross               Genre  Metascore Certificate        Director  Year  \
# 0   $10.06M   Adventure, Family       96.0           U  Hayao Miyazaki  2001
# 1  $422.78M    Adventure, Drama       88.0           U    Roger Allers  1994
# 2       NaN          Drama, War       94.0           U   Isao Takahata  1988
#
#                                          Description  Runtime
# 0  ["\nDuring her family's move to the suburbs, a...  125 min
# 1  ['\nLion prince Simba and his father are targe...   88 min
# 2  ['\nA young boy and his little sister struggle...   89 min

# %% [markdown]
# ### Filtrado por condiciones

# %%
# Generar una lista de resultados booleanos de una condición
condicion_peliculas_miyazaki = df_peliculas['Director'] == 'Hayao Miyazaki'

df_peliculas[condicion_peliculas_miyazaki]
# Out:
#                             Title  Rating    Votes    Gross  \
# 0   Sen to Chihiro no kamikakushi     8.6  747,148  $10.06M
# 7                   Mononoke-hime     8.4  388,925   $2.38M
# 13           Hauru no ugoku shiro     8.2  387,977   $4.71M
# 23               Tonari no Totoro     8.1  333,845   $1.11M
# 36         Tenkû no shiro Rapyuta     8.0  165,250      NaN
# 37       Kaze no tani no Naushika     8.0  168,233      NaN
# 54              Majo no takkyûbin     7.8  143,013      NaN
# 59                   Kaze tachinu     7.7   85,123   $5.21M
# 71                Kurenai no buta     7.7   89,026      NaN
# 79            Gake no ue no Ponyo     7.6  142,408  $15.09M
#
#                   Genre  Metascore Certificate        Director  Year  \
# 0     Adventure, Family       96.0           U  Hayao Miyazaki  2001
# 7    Adventure, Fantasy       76.0           U  Hayao Miyazaki  1997
# 13    Adventure, Family       80.0           U  Hayao Miyazaki  2004
# 23       Comedy, Family       86.0           U  Hayao Miyazaki  1988
# 36    Adventure, Family       78.0           U  Hayao Miyazaki  1986
# 37    Adventure, Sci-Fi       86.0           U  Hayao Miyazaki  1984
# 54    Adventure, Family       83.0           U  Hayao Miyazaki  1989
# 59     Biography, Drama       83.0   Not Rated  Hayao Miyazaki  2013
# 71    Adventure, Comedy       83.0           U  Hayao Miyazaki  1992
# 79    Adventure, Comedy       86.0           U  Hayao Miyazaki  2008
#
#                                           Description  Runtime
# 0   ["\nDuring her family's move to the suburbs, a...  125 min
# 7   ["\nOn a journey to find the cure for a Tatari...  134 min
# 13  ['\nWhen an unconfident young woman is cursed ...  119 min
# 23  ['\nWhen two girls move to the country to be n...   86 min
# 36  ['\nA young boy and a girl with a magic crysta...  125 min
# 37  ['\nWarrior and pacifist Princess Nausicaä des...  117 min
# 54  ['\nA young witch, on her mandatory year of in...  103 min
# 59  ['\nA look at the life of Jiro Horikoshi, the ...  126 min
# 71  ['\nIn 1930s Italy, a veteran World War I pilo...   94 min
# 79  ['\nA five-year-old boy develops a relationshi...  101 min

# %%
# Utilizar dos condiciones
df_peliculas[(condicion_peliculas_miyazaki) & (df_peliculas['Metascore'] > 85.0)]
# Out:
#                             Title  Rating    Votes    Gross  \
# 0   Sen to Chihiro no kamikakushi     8.6  747,148  $10.06M
# 23               Tonari no Totoro     8.1  333,845   $1.11M
# 37       Kaze no tani no Naushika     8.0  168,233      NaN
# 79            Gake no ue no Ponyo     7.6  142,408  $15.09M
#
#                  Genre  Metascore Certificate        Director  Year  \
# 0    Adventure, Family       96.0           U  Hayao Miyazaki  2001
# 23      Comedy, Family       86.0           U  Hayao Miyazaki  1988
# 37   Adventure, Sci-Fi       86.0           U  Hayao Miyazaki  1984
# 79   Adventure, Comedy       86.0           U  Hayao Miyazaki  2008
#
#                                           Description  Runtime
# 0   ["\nDuring her family's move to the suburbs, a...  125 min
# 23  ['\nWhen two girls move to the country to be n...   86 min
# 37  ['\nWarrior and pacifist Princess Nausicaä des...  117 min
# 79  ['\nA five-year-old boy develops a relationshi...  101 min

# %% [markdown]
# ### Manejo de faltantes

# %% [markdown]
# df.dropna()
# df.fillna(df.mean())
# df.replace("a", "b" )

# %%
# Cotejar los valores nulos
df_peliculas.isnull()
# Out:
#     Title  Rating  Votes  Gross  Genre  Metascore  Certificate  Director  \
# 0   False   False  False  False  False      False        False     False
# 1   False   False  False  False  False      False        False     False
# 2   False   False  False   True  False      False        False     False
# 3   False   False  False  False  False      False        False     False
# 4   False   False  False  False  False      False        False     False
# ..    ...     ...    ...    ...    ...        ...          ...       ...
# 80  False   False  False  False  False      False        False     False
# 81  False   False  False  False  False      False        False     False
# 82  False   False  False  False  False      False        False     False
# 83  False   False  False  False  False      False        False     False
# 84  False   False  False  False  False      False        False     False
#
#      Year  Description  Runtime
# 0   False        False    False
# 1   False        False    False
# 2   False        False    False
# 3   False        False    False
# 4   False        False    False
# ..    ...          ...      ...
# 80  False        False    False
# 81  False        False    False
# 82  False        False    False
# 83  False        False    False
# 84  False        False    False
#
# [85 rows x 11 columns]

# %%
# Llenar los valores con la palabar faltante
# df_peliculas.fillna('faltante')

# Llenar los valores faltantes con el promedio de la columna
# df_peliculas.fillna(df_peliculas.mean())

# Llenar los valores faltantes, usando una interpolación
# df_peliculas.interpolate()

# %%
# Eliminar las filas que tengan datos faltantes
df_peliculas = df_peliculas.dropna()

df_peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 84
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        50 non-null     object
#  1   Rating       50 non-null     float64
#  2   Votes        50 non-null     object
#  3   Gross        50 non-null     object
#  4   Genre        50 non-null     object
#  5   Metascore    50 non-null     float64
#  6   Certificate  50 non-null     object
#  7   Director     50 non-null     object
#  8   Year         50 non-null     int64
#  9   Description  50 non-null     object
#  10  Runtime      50 non-null     object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 4.7+ KB

# %% [markdown]
# ### Datos duplicados

# %% [markdown]
# df.unique
# df.duplicated( )
# df.drop_duplicates( , keep= )
# df.index.duplicated()
#
# Referencia: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html

# %%
df_juegos = pd.read_csv('steam-200k.csv' )
df_juegos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   151603712                   199999 non-null  int64
#  1   The Elder Scrolls V Skyrim  199999 non-null  object
#  2   purchase                    199999 non-null  object
#  3   1.0                         199999 non-null  float64
#  4   0                           199999 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 7.6+ MB

# %%
duplicados = df_juegos[df_juegos.duplicated(keep=False)]
duplicados.head()
# Out:
#       151603712                    The Elder Scrolls V Skyrim  purchase  1.0  \
# 1786   11373749                   Sid Meier's Civilization IV  purchase  1.0
# 1967   11373749                   Sid Meier's Civilization IV  purchase  1.0
# 1968   11373749  Sid Meier's Civilization IV Beyond the Sword  purchase  1.0
# 1969   11373749  Sid Meier's Civilization IV Beyond the Sword  purchase  1.0
# 1970   11373749          Sid Meier's Civilization IV Warlords  purchase  1.0
#
#       0
# 1786  0
# 1967  0
# 1968  0
# 1969  0
# 1970  0

# %%
# Eliminar duplicados
df_juegos_limpio = df_juegos.drop_duplicates()

# %%
df_juegos_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199292 entries, 0 to 199998
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   151603712                   199292 non-null  int64
#  1   The Elder Scrolls V Skyrim  199292 non-null  object
#  2   purchase                    199292 non-null  object
#  3   1.0                         199292 non-null  float64
#  4   0                           199292 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 9.1+ MB

# %% [markdown]
# ### Agrupamiento de datos

# %%
# Contabilizar las películas agrupadas por Director
directores = df_peliculas.groupby(['Director'])['Title'].count()
directores.head()
# Out:
# Director
# Andrew Stanton     2
# Bob Persichetti    1
# Brad Bird          4
# Claude Barras      1
# Dean DeBlois       1
# Name: Title, dtype: int64

# %%
# Obtención del total recaudado, agrupado por género y año
peliculas_genero = df_peliculas[['Year','Genre','Gross']].groupby(['Year','Genre']).sum()
peliculas_genero.head(10)
# Out:
#                             Gross
# Year Genre
# 1937  Adventure, Family  $184.93M
# 1940  Family, Fantasy     $76.41M
# 1967  Adventure, Comedy  $141.84M
# 1973  Sci-Fi               $0.19M
# 1988  Adventure, Comedy  $156.45M
#       Comedy, Family       $1.11M
# 1989  Adventure, Comedy  $111.54M
# 1992  Adventure, Comedy  $217.35M
# 1993  Action, Adventure    $5.62M
# 1994  Adventure, Drama   $422.78M

# %% [markdown]
# ### Iteración de valores

# %%
# Iterar el df basándonos en columnas
for columna, contenido in df_peliculas.iteritems():
  # column name
  print(columna)
  # column content
  print(contenido)
# Out:
# Title
# 0          Sen to Chihiro no kamikakushi
# 1                          The Lion King
# 3                         Kimi no na wa.
# 4      Spider-Man: Into the Spider-Verse
# 5                                   Coco
# 6                                 WALL·E
# 7                          Mononoke-hime
# 8                                     Up
# 9                            Toy Story 3
# 10                             Toy Story
# 11                            Inside Out
# 13                  Hauru no ugoku shiro
# 14                          Finding Nemo
# 19              How to Train Your Dragon
# 20                           Ratatouille
# 21                        Monsters, Inc.
# 22                        The Iron Giant
# 23                      Tonari no Totoro
# 30                       The Incredibles
# 33                               Aladdin
# 50                           Sennen joyû
# 51       Cowboy Bebop: Tengoku no tobira
# 53          Batman: Mask of the Phantasm
# 55              Kubo and the Two Strings
# 56                       The Breadwinner
# 57                        Omoide no Mânî
# 58                   Ma vie de Courgette
# 59                          Kaze tachinu
# 60                           Toy Story 4
# 61                        Wreck-It Ralph
# 62                       Le Petit Prince
# 63                        The Lego Movie
# 64                              Papurika
# 66                               Tangled
# 67                              Coraline
# 68          Les triplettes de Belleville
# 69                           Waking Life
# 70    South Park: Bigger, Longer & Uncut
# 72               Who Framed Roger Rabbit
# 73                    La planète sauvage
# 74                              Fantasia
# 76                         Incredibles 2
# 77                                 Moana
# 78                         Despicable Me
# 79                   Gake no ue no Ponyo
# 80                         Kung Fu Panda
# 81                                 Mulan
# 82                    The Little Mermaid
# 83                       The Jungle Book
# 84       Snow White and the Seven Dwarfs
# Name: Title, dtype: object
# Rating
# 0     8.6
# 1     8.5
# 3     8.4
# 4     8.4
# 5     8.4
# 6     8.4
# 7     8.4
# 8     8.3
# 9     8.3
# 10    8.3
# 11    8.2
# 13    8.2
# 14    8.2
# 19    8.1
# 20    8.1
# 21    8.1
# 22    8.1
# 23    8.1
# 30    8.0
# 33    8.0
# 50    7.8
# 51    7.8
# 53    7.8
# 55    7.7
# 56    7.7
# 57    7.7
# 58    7.7
# 59    7.7
# 60    7.7
# 61    7.7
# 62    7.7
# 63    7.7
# 64    7.7
# 66    7.7
# 67    7.7
# 68    7.7
# 69    7.7
# 70    7.7
# 72    7.7
# 73    7.7
# 74    7.7
# 76    7.6
# 77    7.6
# 78    7.6
# 79    7.6
# 80    7.6
# 81    7.6
# 82    7.6
# 83    7.6
# 84    7.6
# Name: Rating, dtype: float64
# Votes
# 0       747,148
# 1     1,041,158
# 3       259,975
# 4       510,227
# 5       492,081
# 6     1,100,175
# 7       388,925
# 8     1,029,395
# 9       826,193
# 10      979,994
# 11      701,106
# 13      387,977
# 14    1,031,038
# 19      730,922
# 20      721,458
# 21      896,964
# 22      192,045
# 23      333,845
# 30      725,314
# 33      412,772
# 50       27,967
# 51       48,674
# 53       50,800
# 55      128,540
# 56       25,319
# 57       40,332
# 58       25,421
# 59       85,123
# 60      245,779
# 61      418,352
# 62       61,997
# 63      352,065
# 64       82,642
# 66      447,447
# 67      224,221
# 68       54,466
# 69       64,147
# 70      204,110
# 72      200,051
# 73       31,226
# 74       96,094
# 76      292,218
# 77      329,295
# 78      542,379
# 79      142,408
# 80      463,897
# 81      284,542
# 82      260,026
# 83      181,528
# 84      197,860
# Name: Votes, dtype: object
# Gross
# 0      $10.06M
# 1     $422.78M
# 3       $5.02M
# 4     $190.24M
# 5     $209.73M
# 6     $223.81M
# 7       $2.38M
# 8     $293.00M
# 9     $415.00M
# 10    $191.80M
# 11    $356.46M
# 13      $4.71M
# 14    $380.84M
# 19    $217.58M
# 20    $206.45M
# 21    $289.92M
# 22     $23.16M
# 23      $1.11M
# 30    $261.44M
# 33    $217.35M
# 50      $0.19M
# 51      $1.00M
# 53      $5.62M
# 55     $48.02M
# 56      $0.31M
# 57      $0.77M
# 58      $0.29M
# 59      $5.21M
# 60    $434.04M
# 61    $189.42M
# 62      $1.34M
# 63    $257.76M
# 64      $0.88M
# 66    $200.82M
# 67     $75.29M
# 68      $7.00M
# 69      $2.89M
# 70     $52.04M
# 72    $156.45M
# 73      $0.19M
# 74     $76.41M
# 76    $608.58M
# 77    $248.76M
# 78    $251.51M
# 79     $15.09M
# 80    $215.43M
# 81    $120.62M
# 82    $111.54M
# 83    $141.84M
# 84    $184.93M
# Name: Gross, dtype: object
# Genre
# 0       Adventure, Family
# 1        Adventure, Drama
# 3          Drama, Fantasy
# 4       Action, Adventure
# 5       Adventure, Comedy
# 6       Adventure, Family
# 7      Adventure, Fantasy
# 8       Adventure, Comedy
# 9       Adventure, Comedy
# 10      Adventure, Comedy
# 11      Adventure, Comedy
# 13      Adventure, Family
# 14      Adventure, Comedy
# 19      Action, Adventure
# 20      Adventure, Comedy
# 21      Adventure, Comedy
# 22      Action, Adventure
# 23         Comedy, Family
# 30      Action, Adventure
# 33      Adventure, Comedy
# 50         Drama, Fantasy
# 51          Action, Crime
# 53      Action, Adventure
# 55      Action, Adventure
# 56          Drama, Family
# 57          Drama, Family
# 58          Comedy, Drama
# 59       Biography, Drama
# 60      Adventure, Comedy
# 61      Adventure, Comedy
# 62       Adventure, Drama
# 63      Action, Adventure
# 64         Drama, Fantasy
# 66      Adventure, Comedy
# 67          Drama, Family
# 68          Comedy, Drama
# 69         Drama, Fantasy
# 70        Comedy, Fantasy
# 72      Adventure, Comedy
# 73                 Sci-Fi
# 74        Family, Fantasy
# 76      Action, Adventure
# 77      Adventure, Comedy
# 78      Adventure, Comedy
# 79      Adventure, Comedy
# 80      Action, Adventure
# 81      Adventure, Comedy
# 82      Adventure, Comedy
# 83      Adventure, Comedy
# 84      Adventure, Family
# Name: Genre, dtype: object
# Metascore
# 0     96.0
# 1     88.0
# 3     79.0
# 4     87.0
# 5     81.0
# 6     95.0
# 7     76.0
# 8     88.0
# 9     92.0
# 10    95.0
# 11    94.0
# 13    80.0
# 14    90.0
# 19    75.0
# 20    96.0
# 21    79.0
# 22    85.0
# 23    86.0
# 30    90.0
# 33    86.0
# 50    70.0
# 51    61.0
# 53    65.0
# 55    84.0
# 56    78.0
# 57    72.0
# 58    85.0
# 59    83.0
# 60    84.0
# 61    72.0
# 62    70.0
# 63    83.0
# 64    81.0
# 66    71.0
# 67    80.0
# 68    91.0
# 69    83.0
# 70    73.0
# 72    83.0
# 73    73.0
# 74    96.0
# 76    80.0
# 77    81.0
# 78    72.0
# 79    86.0
# 80    74.0
# 81    71.0
# 82    88.0
# 83    65.0
# 84    95.0
# Name: Metascore, dtype: float64
# Certificate
# 0             U
# 1             U
# 3             U
# 4             U
# 5             U
# 6             U
# 7             U
# 8             U
# 9             U
# 10            U
# 11            U
# 13            U
# 14            U
# 19            U
# 20            U
# 21            U
# 22            U
# 23            U
# 30            U
# 33            U
# 50           PG
# 51            U
# 53           PG
# 55            U
# 56            U
# 57            U
# 58        PG-13
# 59    Not Rated
# 60            U
# 61            U
# 62           PG
# 63            U
# 64            U
# 66            U
# 67            U
# 68        PG-13
# 69            R
# 70            A
# 72            U
# 73            U
# 74            U
# 76           UA
# 77            U
# 78            U
# 79            U
# 80            U
# 81            U
# 82            U
# 83            U
# 84            U
# Name: Certificate, dtype: object
# Director
# 0           Hayao Miyazaki
# 1             Roger Allers
# 3           Makoto Shinkai
# 4          Bob Persichetti
# 5              Lee Unkrich
# 6           Andrew Stanton
# 7           Hayao Miyazaki
# 8              Pete Docter
# 9              Lee Unkrich
# 10           John Lasseter
# 11             Pete Docter
# 13          Hayao Miyazaki
# 14          Andrew Stanton
# 19            Dean DeBlois
# 20               Brad Bird
# 21             Pete Docter
# 22               Brad Bird
# 23          Hayao Miyazaki
# 30               Brad Bird
# 33            Ron Clements
# 50             Satoshi Kon
# 51    Shin'ichirô Watanabe
# 53           Kevin Altieri
# 55           Travis Knight
# 56             Nora Twomey
# 57    Hiromasa Yonebayashi
# 58           Claude Barras
# 59          Hayao Miyazaki
# 60             Josh Cooley
# 61              Rich Moore
# 62            Mark Osborne
# 63               Phil Lord
# 64             Satoshi Kon
# 66            Nathan Greno
# 67            Henry Selick
# 68          Sylvain Chomet
# 69       Richard Linklater
# 70             Trey Parker
# 72         Robert Zemeckis
# 73             René Laloux
# 74             James Algar
# 76               Brad Bird
# 77            Ron Clements
# 78           Pierre Coffin
# 79          Hayao Miyazaki
# 80            Mark Osborne
# 81           Tony Bancroft
# 82            Ron Clements
# 83     Wolfgang Reitherman
# 84        William Cottrell
# Name: Director, dtype: object
# Year
# 0     2001
# 1     1994
# 3     2016
# 4     2018
# 5     2017
# 6     2008
# 7     1997
# 8     2009
# 9     2010
# 10    1995
# 11    2015
# 13    2004
# 14    2003
# 19    2010
# 20    2007
# 21    2001
# 22    1999
# 23    1988
# 30    2004
# 33    1992
# 50    2001
# 51    2001
# 53    1993
# 55    2016
# 56    2017
# 57    2014
# 58    2016
# 59    2013
# 60    2019
# 61    2012
# 62    2015
# 63    2014
# 64    2006
# 66    2010
# 67    2009
# 68    2003
# 69    2001
# 70    1999
# 72    1988
# 73    1973
# 74    1940
# 76    2018
# 77    2016
# 78    2010
# 79    2008
# 80    2008
# 81    1998
# 82    1989
# 83    1967
# 84    1937
# Name: Year, dtype: int64
# Description
# 0     ["\nDuring her family's move to the suburbs, a...
# 1     ['\nLion prince Simba and his father are targe...
# 3     ['\nTwo strangers find themselves linked in a ...
# 4     ['\nTeen Miles Morales becomes the Spider-Man ...
# 5     ["\nAspiring musician Miguel, confronted with ...
# 6     ['\nIn the distant future, a small waste-colle...
# 7     ["\nOn a journey to find the cure for a Tatari...
# 8     ['\n78-year-old Carl Fredricksen travels to Pa...
# 9     ["\nThe toys are mistakenly delivered to a day...
# 10    ["\nA cowboy doll is profoundly threatened and...
# 11    ['\nAfter young Riley is uprooted from her Mid...
# 13    ['\nWhen an unconfident young woman is cursed ...
# 14    ['\nAfter his son is captured in the Great Bar...
# 19    ['\nA hapless young Viking who aspires to hunt...
# 20    ['\nA rat who can cook makes an unusual allian...
# 21    ['\nIn order to power the city, monsters have ...
# 22    ['\nA young boy befriends a giant robot from o...
# 23    ['\nWhen two girls move to the country to be n...
# 30    ['\nWhile trying to lead a quiet suburban life...
# 33    ['\nA kindhearted street urchin and a power-hu...
# 50    ['\nA TV interviewer and his cameraman meet a ...
# 51    ["\nA terrorist explosion releases a deadly vi...
# 53    ['\nBatman is wrongly implicated in a series o...
# 55    ['\nA young boy named Kubo must locate a magic...
# 56    ['\nIn 2001, Afghanistan is under the control ...
# 57    ["\nDue to 12 y.o. Anna's asthma, she's sent t...
# 58    ['\nAfter losing his mother, a young boy is se...
# 59    ['\nA look at the life of Jiro Horikoshi, the ...
# 60    ['\nWhen a new toy called "Forky" joins Woody ...
# 61    ['\nA video game villain wants to be a hero an...
# 62    ['\nA little girl lives in a very grown-up wor...
# 63    ['\nAn ordinary LEGO construction worker, thou...
# 64    ["\nWhen a machine that allows therapists to e...
# 66    ['\nThe magically long-haired Rapunzel has spe...
# 67    ['\nAn adventurous 11-year-old girl finds anot...
# 68    ['\nWhen her grandson is kidnapped during the ...
# 69    ['\nA man shuffles through a dream meeting var...
# 70    ['\nWhen Stan Marsh and his friends go see an ...
# 72    ["\nA toon-hating detective is a cartoon rabbi...
# 73    ['\nOn a faraway planet where blue giants rule...
# 74    ['\nA collection of animated interpretations o...
# 76    ['\nThe Incredibles family takes on a new miss...
# 77    ["\nIn Ancient Polynesia, when a terrible curs...
# 78    ['\nWhen a criminal mastermind uses a trio of ...
# 79    ['\nA five-year-old boy develops a relationshi...
# 80    ["\nTo everyone's surprise, including his own,...
# 81    ["\nTo save her father from death in the army,...
# 82    ["\nA mermaid princess makes a Faustian bargai...
# 83    ['\nBagheera the Panther and Baloo the Bear ha...
# 84    ['\nExiled into the dangerous forest by her wi...
# Name: Description, dtype: object
# Runtime
# 0     125 min
# 1      88 min
# 3     106 min
# 4     117 min
# 5     105 min
# 6      98 min
# 7     134 min
# 8      96 min
# 9     103 min
# 10     81 min
# 11     95 min
# 13    119 min
# 14    100 min
# 19     98 min
# 20    111 min
# 21     92 min
# 22     86 min
# 23     86 min
# 30    115 min
# 33     90 min
# 50     87 min
# 51    115 min
# 53     76 min
# 55    101 min
# 56     94 min
# 57    103 min
# 58     66 min
# 59    126 min
# 60    100 min
# 61    101 min
# 62    108 min
# 63    100 min
# 64     90 min
# 66    100 min
# 67    100 min
# 68     80 min
# 69     99 min
# 70     81 min
# 72    104 min
# 73     72 min
# 74    125 min
# 76    118 min
# 77    107 min
# 78     95 min
# 79    101 min
# 80     92 min
# 81     88 min
# 82     83 min
# 83     78 min
# 84     83 min
# Name: Runtime, dtype: object

# %%
# Iterar el df basándonos en filas
for index, row in df_peliculas.iterrows():
    print(row['Title'], row['Genre'])
# Out:
# Sen to Chihiro no kamikakushi  Adventure, Family
# The Lion King  Adventure, Drama
# Kimi no na wa.  Drama, Fantasy
# Spider-Man: Into the Spider-Verse  Action, Adventure
# Coco  Adventure, Comedy
# WALL·E  Adventure, Family
# Mononoke-hime  Adventure, Fantasy
# Up  Adventure, Comedy
# Toy Story 3  Adventure, Comedy
# Toy Story  Adventure, Comedy
# Inside Out  Adventure, Comedy
# Hauru no ugoku shiro  Adventure, Family
# Finding Nemo  Adventure, Comedy
# How to Train Your Dragon  Action, Adventure
# Ratatouille  Adventure, Comedy
# Monsters, Inc.  Adventure, Comedy
# The Iron Giant  Action, Adventure
# Tonari no Totoro  Comedy, Family
# The Incredibles  Action, Adventure
# Aladdin  Adventure, Comedy
# Sennen joyû  Drama, Fantasy
# Cowboy Bebop: Tengoku no tobira  Action, Crime
# Batman: Mask of the Phantasm  Action, Adventure
# Kubo and the Two Strings  Action, Adventure
# The Breadwinner  Drama, Family
# Omoide no Mânî  Drama, Family
# Ma vie de Courgette  Comedy, Drama
# Kaze tachinu  Biography, Drama
# Toy Story 4  Adventure, Comedy
# Wreck-It Ralph  Adventure, Comedy
# Le Petit Prince  Adventure, Drama
# The Lego Movie  Action, Adventure
# Papurika  Drama, Fantasy
# Tangled  Adventure, Comedy
# Coraline  Drama, Family
# Les triplettes de Belleville  Comedy, Drama
# Waking Life  Drama, Fantasy
# South Park: Bigger, Longer & Uncut  Comedy, Fantasy
# Who Framed Roger Rabbit  Adventure, Comedy
# La planète sauvage  Sci-Fi
# Fantasia  Family, Fantasy
# Incredibles 2  Action, Adventure
# Moana  Adventure, Comedy
# Despicable Me  Adventure, Comedy
# Gake no ue no Ponyo  Adventure, Comedy
# Kung Fu Panda  Action, Adventure
# Mulan  Adventure, Comedy
# The Little Mermaid  Adventure, Comedy
# The Jungle Book  Adventure, Comedy
# Snow White and the Seven Dwarfs  Adventure, Family

# %% [markdown]
# ### Apply

# %% [markdown]
# Método que nos permite aplicar funciones al df

# %%
# Función que cambia el valor de un número a Pesos Mexicanos
def convertir_pesos(valor):
    return valor * 20

# %%
# Aplicar la función
df_libros['price'] = df_libros['price'].apply(convertir_pesos)

# %%
# Aplicar la misma función utilizando una lambda
# df_libros['price'] = df_libros['price'].apply(lambda x: x * 20)

# Aplicación de lambda con condicionales
# df['Result'] = df['Maths'].apply(lambda x: 'Pass' if x>=5 else 'Fail')

# Fuente: https://www.geeksforgeeks.org/using-apply-in-pandas-lambda-functions-with-multiple-if-statements/

# %%
df_libros
# Out:
#        id                author                                   title  \
# 0   bk101  Gambardella, Matthew                   XML Developer's Guide
# 1   bk102            Ralls, Kim                           Midnight Rain
# 2   bk103           Corets, Eva                         Maeve Ascendant
# 3   bk104           Corets, Eva                         Oberon's Legacy
# 4   bk105           Corets, Eva                      The Sundered Grail
# 5   bk106      Randall, Cynthia                             Lover Birds
# 6   bk107        Thurman, Paula                           Splish Splash
# 7   bk108         Knorr, Stefan                         Creepy Crawlies
# 8   bk109          Kress, Peter                            Paradox Lost
# 9   bk110          O'Brien, Tim   Microsoft .NET: The Programming Bible
# 10  bk111          O'Brien, Tim           MSXML3: A Comprehensive Guide
# 11  bk112           Galos, Mike  Visual Studio 7: A Comprehensive Guide
#
#               genre  price publish_date  \
# 0          Computer  899.0   2000-10-01
# 1           Fantasy  119.0   2000-12-16
# 2           Fantasy  119.0   2000-11-17
# 3           Fantasy  119.0   2001-03-10
# 4           Fantasy  119.0   2001-09-10
# 5           Romance   99.0   2000-09-02
# 6           Romance   99.0   2000-11-02
# 7            Horror   99.0   2000-12-06
# 8   Science Fiction  139.0   2000-11-02
# 9          Computer  739.0   2000-12-09
# 10         Computer  739.0   2000-12-01
# 11         Computer  999.0   2001-04-16
#
#                                           description
# 0   An in-depth look at creating applications \n  ...
# 1   A former architect battles corporate zombies, ...
# 2   After the collapse of a nanotechnology \n     ...
# 3   In post-apocalypse England, the mysterious \n ...
# 4   The two daughters of Maeve, half-sisters, \n  ...
# 5   When Carla meets Paul at an ornithology \n    ...
# 6   A deep sea diver finds true love twenty \n    ...
# 7   An anthology of horror stories about roaches,\...
# 8   After an inadvertant trip through a Heisenberg...
# 9   Microsoft's .NET initiative is explored in \n ...
# 10  The Microsoft MSXML3 parser is covered in \n  ...
# 11  Microsoft Visual Studio 7 is explored in depth...

# %% [markdown]
# ### Combinación de dataframes

# %% [markdown]
# ![imagen.png](attachment:imagen.png)
# ![imagen-2.png](attachment:imagen-2.png)

# %%
# Créditos dfs https://www.tutorialspoint.com/python_pandas/python_pandas_merging_joining.htm
left = pd.DataFrame({
   'id':[1,2,3,4,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5']})
right = pd.DataFrame(
   {'id_new':[1,2,3,4,5],
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5']})

# %% [markdown]
# #### Concat

# %%
# Unir mediante concat, utilizando las filas
pd.concat([left,right], ignore_index=True)
# Out:
#    id    Name subject_id
# 0   1    Alex       sub1
# 1   2     Amy       sub2
# 2   3   Allen       sub4
# 3   4   Alice       sub6
# 4   5  Ayoung       sub5
# 5   1   Billy       sub2
# 6   2   Brian       sub4
# 7   3    Bran       sub3
# 8   4   Bryce       sub6
# 9   5   Betty       sub5

# %%
# Unir mediante concat, utilizando las columnas
pd.concat([left,right], axis=1)
# Out:
#    id    Name subject_id  id   Name subject_id
# 0   1    Alex       sub1   1  Billy       sub2
# 1   2     Amy       sub2   2  Brian       sub4
# 2   3   Allen       sub4   3   Bran       sub3
# 3   4   Alice       sub6   4  Bryce       sub6
# 4   5  Ayoung       sub5   5  Betty       sub5

# %% [markdown]
# #### Merge

# %%
# Left join
left.merge(right, on='subject_id')
# Out:
#    id_x  Name_x subject_id  id_y Name_y
# 0     2     Amy       sub2     1  Billy
# 1     3   Allen       sub4     2  Brian
# 2     4   Alice       sub6     4  Bryce
# 3     5  Ayoung       sub5     5  Betty

# %%
# Si el nombre de la columna tiene nombre diferente pero se puede hacer la unión
# left.merge(right, left_on='id', right_on="id_new")

# Indicar el tipo de join mediante el atributo
# how="left", "inner", "right"

# %% [markdown]
# #### Join

# %%
left_n = pd.DataFrame({
   'a':[1,2,3,4,5],
   'b': [3,4,6,8,7],
   'c':[9,5,3,7,6]},
    index=['i1', 'i2', 'i3', 'i4', 'i6'])
right_n = pd.DataFrame(
   {'d':[1,2,3,4,5],
   'e': [6,5,7,4,3]},
    index=['i1', 'i2', 'i4', 'i5', 'i9'])

# %%
# Se puede indicar el tipo de join usando el atributo how=
left_n.join(right_n, how='right')
# Out:
#       a    b    c  d  e
# i1  1.0  3.0  9.0  1  6
# i2  2.0  4.0  5.0  2  5
# i4  4.0  8.0  7.0  3  7
# i5  NaN  NaN  NaN  4  4
# i9  NaN  NaN  NaN  5  3
